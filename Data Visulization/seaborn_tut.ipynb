# %% [markdown]
# ## Seaborn

# %% [markdown]
# ### Types of Functions
# - Figure Function
# - Axes Function
#
# ### Main Classification
# - Relational Graphs (scatter, lineplot)
# - Dist plot (Histogram, kdeplot, rugplot)
# - Catagorical (Barplot, boxplot, count plot, violin, swarmplot)
# - Matrix Plot (heatmap, clusterplot)
# - Multiplots (pair plot, joint plot)

# %%
import seaborn as sns

# %% [markdown]
# ## Relational Graph
# - Scatter Plot
# - Line plot

# %%
# scatter plot
tips =sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# scatter plot --> Axes function
sns.scatterplot(data =tips, x ="total_bill",y ="tip", hue ="sex", style="time", size ="size")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# figure lvl function
sns.relplot(data =tips, x ="total_bill", y ="tip", kind ="scatter", hue="sex", style="time", size ="size")

# %%
import plotly.express as px

# %%
gap =px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
tmp =gap[gap["country"]=="Pakistan"]
tmp
# Out:
#        country continent  year  lifeExp        pop    gdpPercap iso_alpha  \
# 1164  Pakistan      Asia  1952   43.436   41346560   684.597144       PAK
# 1165  Pakistan      Asia  1957   45.557   46679944   747.083529       PAK
# 1166  Pakistan      Asia  1962   47.670   53100671   803.342742       PAK
# 1167  Pakistan      Asia  1967   49.800   60641899   942.408259       PAK
# 1168  Pakistan      Asia  1972   51.929   69325921  1049.938981       PAK
# 1169  Pakistan      Asia  1977   54.043   78152686  1175.921193       PAK
# 1170  Pakistan      Asia  1982   56.158   91462088  1443.429832       PAK
# 1171  Pakistan      Asia  1987   58.245  105186881  1704.686583       PAK
# 1172  Pakistan      Asia  1992   60.838  120065004  1971.829464       PAK
# 1173  Pakistan      Asia  1997   61.818  135564834  2049.350521       PAK
# 1174  Pakistan      Asia  2002   63.610  153403524  2092.712441       PAK
# 1175  Pakistan      Asia  2007   65.483  169270617  2605.947580       PAK
#
# ...

# %%
# lineplot
sns.lineplot(data =tmp, x ="year", y ="lifeExp")
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.relplot(data =tmp, x ="year", y ="lifeExp", kind ="line")

# %%
tmp =gap[gap["country"].isin(["Pakistan" , "India", "Brazil"])]
tmp
# Out:
#        country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 168     Brazil  Americas  1952   50.917    56602560  2108.944355       BRA
# 169     Brazil  Americas  1957   53.285    65551171  2487.365989       BRA
# 170     Brazil  Americas  1962   55.665    76039390  3336.585802       BRA
# 171     Brazil  Americas  1967   57.632    88049823  3429.864357       BRA
# 172     Brazil  Americas  1972   59.504   100840058  4985.711467       BRA
# 173     Brazil  Americas  1977   61.489   114313951  6660.118654       BRA
# 174     Brazil  Americas  1982   63.336   128962939  7030.835878       BRA
# 175     Brazil  Americas  1987   65.205   142938076  7807.095818       BRA
# 176     Brazil  Americas  1992   67.057   155975974  6950.283021       BRA
# 177     Brazil  Americas  1997   69.388   168546719  7957.980824       BRA
# 178     Brazil  Americas  2002   71.006   179914212  8131.212843       BRA
# ...

# %%
sns.relplot(data =tmp, x ="year", y ="lifeExp", kind ="line", hue ="country", style ="continent", size ="continent")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# facet plot
# col ="gender" --> Two differ col for gender
sns.relplot(data =tips, x ="total_bill", y ="tip", col ="smoker", row ="sex")

# %% [markdown]
# ## Distribution Graph
# - Univariate Analysis
# - To Find Distrubution
# - Plots --> Histogram, kdeplot, rugplot

# %%
# axis level
sns.histplot(data =tips, x ="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# figure lvl
sns.displot(data =tips , x ="total_bill", kind ="hist")

# %%
# bins
sns.displot(data =tips , x ="total_bill", kind ="hist", bins =50)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# element =step --> To make it glassy look
sns.displot(data =tips , x ="total_bill", kind ="hist", hue ="sex", element ="step")

# %%
# can make it side by side using col
sns.displot(data =tips , x ="total_bill", kind ="hist", col ="sex")

# %%
sns.kdeplot(data =tips , x="total_bill", hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.rugplot(data =tips , x="total_bill", hue="sex")
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# ## Matrix
# - HeatMap
# - ClusterMap

# %%
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
grid =gap.pivot_table(index ="country", columns= "year", values="lifeExp", aggfunc="sum")
grid
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(10, 30))
# annot =true to get actual value
sns.heatmap(grid, annot=True, linewidth =0.5)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %% [markdown]
# ## Catagorical Plots

# %% [markdown]
# ## Catagorical Scatter Plots

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# stripplot --> Scatter plot for one catagorical and numerical
sns.stripplot(data =tips, x ="day", y ="total_bill", jitter=False, hue ="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# figure level function
sns.catplot(data =tips, x ="day", y ="total_bill", kind ="strip", jitter =False)

# %%
# swarm plot
sns.catplot(data =tips, x ="day", y ="total_bill", kind ="swarm", hue="sex")

# %% [markdown]
# ## Catagorical Dist Plot

# %%
# boxplot
sns.boxplot(data =tips, y ="total_bill")
# Out:
# <Axes: ylabel='total_bill'>

# %%
# boxplot
sns.boxplot(data =tips ,x ="sex",y ="total_bill", hue="day")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# voilinplot --> kde + boxplot
sns.violinplot(data =tips,x ="sex", y ="total_bill")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.kdeplot(data =tips, x ="total_bill", hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## Bar Plot

# %%
sns.barplot(data=tips, x ="sex")
# Out:
# <Axes: xlabel='sex'>

# %%
type(sns.pairplot(tips[["total_bill", "tip", "sex"]], hue="sex"))
# Out:
# seaborn.axisgrid.PairGrid

# %%
import pandas as pd
data =pd.DataFrame({"Product": [1,2,1,2], "Quarter": [1,1,2,2], "Sales":[10, 20, 30, 40]})
data
# Out:
#    Product  Quarter  Sales
# 0        1        1     10
# 1        2        1     20
# 2        1        2     30
# 3        2        2     40

# %%
g =data.groupby("Product")

# %%
for group, data in g:
    q =data.groupby("Quarter").sum().reset_index()
    plt.scatter(q["Quarter"], q["Sales"])
